# %%
from micrograd.graph import Dag
from micrograd.drawing import Drawing

# %%
dag: Dag[None] = Dag()
a = dag.node(None, label='a')
b = dag.node(None, label='b')
c = dag.node(None, a, b, label='c')
d = dag.node(None, a, c, label='d')
e = dag.node(None, a, label='e')
f = dag.node(None, label='f')
g = dag.node(None, b, f, c, label='g')
h = dag.node(None, e, g, label='h')

Drawing().draw_underlying(dag)
