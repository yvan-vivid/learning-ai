# %%
from functools import partial
from pathlib import Path
from torch import tensor, long
from torch.optim import AdamW

from karpathy_series.makemore.encoding.character import CharacterSet, CharacterEncoder
from karpathy_series.makemore.data import read_character_data
from karpathy_series.gpt_from_scratch.data import SequenceDataSplit
from karpathy_series.gpt_from_scratch.batch_generation import SequentialBlockBatchGenerator
from karpathy_series.gpt_from_scratch.training import Trainer
from karpathy_series.gpt_from_scratch.components.models.bigram import BigramModel

# %% [markdown]
# ## Data

# %%
data_path = Path("../../data/shakespeare.txt")
text_data = read_character_data(data_path)

# %%
char_set = CharacterSet.from_text(text_data)
char_encoder = CharacterEncoder.from_charset(char_set)
print(f"Token set size = {char_encoder.size}")
# Out:
# Token set size = 65

# %%
data = tensor(char_encoder.encodes(text_data), dtype=long)
print(f"Full data length = {len(data)}")
# Out:
# Full data length = 1115394

# %%
splitter = SequenceDataSplit(90, 10)
data_split = splitter(data)
print(f"Split: {len(data_split.training)} training, {len(data_split.validation)} validation")
# Out:
# Split: 1003854 training, 111540 validation

# %%
window_length = 8
model = BigramModel(char_encoder.size, window_length)
batcher = partial(SequentialBlockBatchGenerator, block_size=window_length, batch_size=4)
optimizer = AdamW(model.parameters(), lr=1e-3)
trainer = Trainer(model, optimizer, batcher, data_split)

# %%
trainer.train(40000, 10)
# Out:
# step = 0, training loss = 4.738, validation loss = 4.753
# step = 4000, training loss = 3.016, validation loss = 3.024
# step = 8000, training loss = 2.566, validation loss = 2.678
# step = 12000, training loss = 2.538, validation loss = 2.553
# step = 16000, training loss = 2.474, validation loss = 2.490
# step = 20000, training loss = 2.433, validation loss = 2.466
# step = 24000, training loss = 2.480, validation loss = 2.495
# step = 28000, training loss = 2.429, validation loss = 2.498
# step = 32000, training loss = 2.474, validation loss = 2.473
# step = 36000, training loss = 2.440, validation loss = 2.461

# %%
def render_generated(generated):
    return (char_encoder.decode_str(row.tolist()) for row in generated)

for out in render_generated(model.generate_from_init(1000)):
    print(out)
# Out:
# CEN n, s whthisaid bat wos s hepathictom Rowe ly. fivenougin te al h, If?
# ARDYO:
# KICheinisieiou my ire med the.
# ASp mifooue.
# TIN foute,
# WAngy w ous ide VIN:
# DYonsh n:
#
# O:
#
# MA D d theve mo INCoutck'send cence t afotht s cl; n f '
# TEd:
# Weind tat bl DYo SSSedalerizce y mar o th my
# Whr cre,
# Asoralashe. insoft,
# I:
# TENGSo?
# Bhallor binee t, mounve thaty mpintig h;
# K:
# Whinf
# BEl IO:
# LETy '
# pim f. wisance eve s?--of m m.
# Grnoovintht d
# irveshelk cothode we abstofeme eend thad me, ngm wit ors o n he?
# AUMomen wis d.
# S:
#
#
# Whin s;
# Thiseng, tho, gu rk by sot IXYoty t hay's cas.
# Pre I, ghouar s, thesop me y sou ther:
# Ty ithy ERDWonoustin;
# Any ato 'sest cewor womofas
# Mug,
# Delaime crl tood ll, is roomagosey theiolo pyomeremecoveaicern,
# INu chead t iust,
# HA: y,
# WAnain, mitofofl t thtimed ulel!
# I'ms omy t RDWhansthan achalldsst,
# Be cey CHerrirster:
# My bo:
# Whit RD fay tikshar:
#
# CARI hes
#
#
# pprofedint? MARD END t hir k, o tomyotldwere a 'sbon.
# Thoithetwne p if y y &QUCEDove d:
# MIEOrathar we Sp;
# Arnd m, merd V
