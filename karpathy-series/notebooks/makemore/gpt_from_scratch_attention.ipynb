# %%
from pathlib import Path
from torch import tensor, long, zeros
from torch.optim import AdamW

from karpathy_series.makemore.encoding.character import CharacterSet, CharacterEncoder
from karpathy_series.makemore.data import read_character_data
from karpathy_series.gpt_from_scratch.data import SequenceDataSplit
from karpathy_series.gpt_from_scratch.batch_generation import SequentialBlockBatchGenerator
from karpathy_series.gpt_from_scratch.training import Trainer
from karpathy_series.gpt_from_scratch.components.models.attention import AttentionModel

# %%
data_path = Path("../../data/shakespeare.txt")
text_data = read_character_data(data_path)
char_set = CharacterSet.from_text(text_data)
char_encoder = CharacterEncoder.from_charset(char_set)
data = tensor(char_encoder.encodes(text_data), dtype=long)
splitter = SequenceDataSplit(90, 10)
data_split = splitter(data)
print(f"Split: {len(data_split.training)} training, {len(data_split.validation)} validation")
# Out:
# Split: 1003854 training, 111540 validation

# %%
window_length = 8
embedding_dims = 32
head_dims = 8
head_count = 4
model = AttentionModel(char_encoder.size, window_length, embedding_dims, head_count, head_dims)
batcher = lambda data: SequentialBlockBatchGenerator(data, window_length, 4)
optimizer = AdamW(model.parameters(), lr=1e-3)
trainer = Trainer(model, optimizer, batcher, data_split)

# %%
trainer.train(40000, 10)
# Out:
# step = 0, training loss = 4.435, validation loss = 4.404
# step = 4000, training loss = 2.553, validation loss = 2.571
# step = 8000, training loss = 2.440, validation loss = 2.459
# step = 12000, training loss = 2.389, validation loss = 2.442
# step = 16000, training loss = 2.365, validation loss = 2.372
# step = 20000, training loss = 2.319, validation loss = 2.403
# step = 24000, training loss = 2.296, validation loss = 2.338
# step = 28000, training loss = 2.240, validation loss = 2.268
# step = 32000, training loss = 2.235, validation loss = 2.261
# step = 36000, training loss = 2.289, validation loss = 2.282

# %%
# start = model.initial()
start = zeros(1, 8, dtype=int)
for row in model.generate(start, 1000):
    print(char_encoder.decode_str(row.tolist()))
# Out:
#  do spor is flacen a bll. girser me?
#
# Shan omeofeoock
# Of crnarticke, twhe an I s lince thear dow, hembeank ove frisern, forsther,
# e, anaste mencengeantate;
# And babluteds
# Af doyursidich this bisp do and brotin.
#
# TERleplomse rwnouse hath whreo, rey;
# Rart you ro bre
# Wickefs.
# VI theavest dand es,
# Lacen he ward, a of hire de.
# Menty hep thase theax, wiryyiburmsos:
# Whalller home re kincanse.
#
# That then ands?
# Ye,
# Hrwador Ed,
# M maimed a you pper;
# ford.
#
# Weand, ansoni's ll! in yourd. note mu
# trehd fryt all
# Nop mere I a wid rery as; shord Juf werisingh'der? pold
# Anss.
#
# ISABRD I:
# I I wit 'ser'd OF roven I spor oment,
# Meectoman, bay,-Sh you
# He thath pit, cry mancave is so, I hanee younpr yourndy; yimen crource, CI fitherd and a und thald herer: apncends swind's,
# Wher sald soffmeen;
# I wis ite aroude ul ivede pind roe shathills poe; brosour aghoter with'll Instou that andsedy inghse nisn kischise glend whirm,air
# tesw'
# Why yearlled I anderw.
# I'Thou ot coulll is cren, lash thoncomfaiels;
# Qames I's it
